# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
df = pd.merge(mouse_metadata, study_results, how = 'outer', on = 'Mouse ID')

# Display the data table for preview
df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
count_df = df.drop_duplicates('Mouse ID', keep= 'first', inplace= False)['Mouse ID'].count()
count_df
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
group_df = df.groupby('Mouse ID').count()
group_df = group_df.sort_values('Timepoint', ascending= False)    
group_df
# Out:
#           Drug Regimen  Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989                13   13          13          13         13
# a203                10   10          10          10         10
# n364                10   10          10          10         10
# m546                10   10          10          10         10
# m550                10   10          10          10         10
# ...                ...  ...         ...         ...        ...
# x226                 1    1           1           1          1
# b447                 1    1           1           1          1
# f932                 1    1           1           1          1
# l872                 1    1           1           1          1
# n482                 1    1           1           1          1
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# g989                      13                13
# a203                      10                10
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_df = group_df[group_df.Timepoint > 10].filter(['Mouse ID'])
duplicate_df = pd.merge(df, duplicate_df, on = 'Mouse ID')
duplicate_df
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      g989     Propriva  Female          21          26          0
# 1      g989     Propriva  Female          21          26          0
# 2      g989     Propriva  Female          21          26          5
# 3      g989     Propriva  Female          21          26          5
# 4      g989     Propriva  Female          21          26         10
# 5      g989     Propriva  Female          21          26         10
# 6      g989     Propriva  Female          21          26         15
# 7      g989     Propriva  Female          21          26         15
# 8      g989     Propriva  Female          21          26         20
# 9      g989     Propriva  Female          21          26         20
# 10     g989     Propriva  Female          21          26         25
# 11     g989     Propriva  Female          21          26         30
# 12     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
df = df[~df['Mouse ID'].isin(duplicate_df['Mouse ID'])]
df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
count_df = df.drop_duplicates('Mouse ID', keep= 'first', inplace= False)['Mouse ID'].count()
count_df
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
regimen_df = df.groupby('Drug Regimen')

reg_mean = regimen_df['Tumor Volume (mm3)'].mean()
reg_med = regimen_df['Tumor Volume (mm3)'].median()
reg_var = regimen_df['Tumor Volume (mm3)'].var()
reg_std = regimen_df['Tumor Volume (mm3)'].std()
reg_sem = regimen_df['Tumor Volume (mm3)'].sem()

summary_df = pd.DataFrame({'Mean': reg_mean, 'Median': reg_med, 'Variance': reg_var, 'Standard Deviation': reg_std, 'SEM': reg_sem})
summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
agg_df = df.groupby('Drug Regimen')
# Using the aggregation method, produce the same summary statistics in a single line
agg_df.agg(['mean', 'median','var', 'std', 'sem'])['Tumor Volume (mm3)']
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
barplot = df['Drug Regimen'].value_counts().plot.bar()
#x/y axis labels
barplot.set_xlabel('Regimen')
barplot.set_ylabel('Number of Measurements')
# Out:
# Text(0, 0.5, 'Number of Measurements')

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
measurement_count = df['Drug Regimen'].value_counts()
x = np.arange(len(measurement_count))
plt.bar(x, measurement_count)
#create tick labels based on drug name
ticks = [value for value in x]
plt.xticks(ticks, measurement_count.index.values, rotation = 90)
#x/y axis labels
plt.xlabel('Regimen')
plt.ylabel('Number of Measurements')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
sex_data = df['Sex'].value_counts()
#generate pie chart
pie = sex_data.plot.pie(autopct = '%1.1f%%', startangle = 90, title = 'Sex Demographics')
#get rid of y label
pie.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex_data = df['Sex'].value_counts()
#generate pie chart
plt.pie (sex_data, labels = sex_data.index.values, autopct = '%1.1f%%', startangle = 90)
plt.title('Sex Demographics')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
drugs = ['Capomulin','Ramicane','Infubinol','Ceftamin']
# Start by getting the last (greatest) timepoint for each mouse
max_tp = pd.DataFrame(df.groupby('Mouse ID')['Timepoint'].max()).rename(columns={'Timepoint': 'Max Timepoint'})

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_df = pd.merge(df, max_tp, on = 'Mouse ID')
merged_df.loc[merged_df['Drug Regimen'].isin(drugs)]
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 1        k403     Ramicane    Male          21          16          5
# 2        k403     Ramicane    Male          21          16         10
# 3        k403     Ramicane    Male          21          16         15
# 4        k403     Ramicane    Male          21          16         20
# ...       ...          ...     ...         ...         ...        ...
# 1855     z581    Infubinol  Female          24          25         25
# 1856     z581    Infubinol  Female          24          25         30
# 1857     z581    Infubinol  Female          24          25         35
# 1858     z581    Infubinol  Female          24          25         40
# 1859     z581    Infubinol  Female          24          25         45
#
#       Tumor Volume (mm3)  Metastatic Sites  Max Timepoint
# 0              45.000000                 0             45
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

### Already created in previous cell

# Create empty list to fill with tumor vol data (for plotting)
tumor_val = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

for drug in drugs:  

    # Locate the rows which contain mice on each drug and get the tumor volumes
    temp_df = merged_df.loc[merged_df['Drug Regimen'] == drug]
    final_vol_df = temp_df.loc[temp_df['Timepoint'] == temp_df['Max Timepoint']]
    
    values = final_vol_df['Tumor Volume (mm3)']
    tumor_val.append(values)
    
    # add subset 
    
    
    
    ### Calc IQR for each drug
    quartiles = values.quantile([.25, .5, .75])
    lowerq = quartiles[.25]
    upperq = quartiles[.75]
    iqr = upperq-lowerq
    print(f'IQR for {drug}: {iqr}')
    
    # Determine outliers using upper and lower bounds
    lowerb = lowerq - (1.5*iqr)
    upperb = upperq + (1.5*iqr)
    outlier_count = (values.loc[(final_vol_df['Tumor Volume (mm3)']>= upperb) | (final_vol_df['Tumor Volume (mm3)']<= lowerb)]).count()
    
    print(f'Number of outliers for {drug}: {outlier_count}')
# Out:
# IQR for Capomulin: 7.781863460000004
# Number of outliers for Capomulin: 0
# IQR for Ramicane: 9.098536719999998
# Number of outliers for Ramicane: 0
# IQR for Infubinol: 11.477135160000003
# Number of outliers for Infubinol: 1
# IQR for Ceftamin: 15.577752179999997
# Number of outliers for Ceftamin: 0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

plt.boxplot(tumor_val)
plt.xticks([1,2,3,4],['Capomulin','Ramicane', 'Infubinol', 'Ceftamin'])
plt.title('Final Tumor Volumes')
plt.ylabel('Final Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

#select random mouse under Capomulin treatment
mouse_df = df.loc[df['Drug Regimen'] == 'Capomulin'].sample()
mouse_df = mouse_df.reset_index(drop=True)


#single out mouse
ID = mouse_df.iloc[0,0]
mouse_data = df.loc[df['Mouse ID'] == ID]

#create plot
plt.plot(mouse_data['Timepoint'], mouse_data['Tumor Volume (mm3)'], marker = 'o')
plt.xlabel('Time (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title(f'Capomulin Treatment for mouse' + ' ' + ID)
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capo_df = df.loc[df['Drug Regimen'] == 'Capomulin']

avg_vol_df = pd.DataFrame(capo_df.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()).reset_index().rename(columns={'Tumor Volume (mm3)': 'Average Tumor Volume'})
merged_df = pd.merge(capo_df, avg_vol_df, on = 'Mouse ID')
avg_vol_df = merged_df[['Weight (g)', 'Average Tumor Volume']].drop_duplicates()

#define variables/create plot
x = avg_vol_df['Weight (g)']
y = avg_vol_df['Average Tumor Volume']

plt.scatter(x,y)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title('Average Tumor Volume by Weight')
# Out:
# Text(0.5, 1.0, 'Average Tumor Volume by Weight')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
coeff = st.pearsonr(x,y)

#linear regression
(m, b, r, p, std) = linregress(x, y)
reg_values = m*x + b
line = "y = " + str(round(m,2)) + "x + " + str(round(b,2))

# generate plot
plt.scatter(x,y)
plt.plot(x,reg_values,"r-")


#labels and annotation
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Average Tumor Volume by Weight')
plt.annotate(line,(20,35),fontsize=12,color="red")
plt.show()
